\\u003Ca href\x3d\\\x22/history\\\x22\\u003E웹 기록\\u003C/a\\u003E에서 삭제되었습니다.\x22,\x22psrl\x22:\x22삭제\x22,\x22sbit\x22:\x22이미지로 검색\x22,\x22srch\x22:\x22Google 검색\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22refpd\x22:true,\x22refspre\x22:true,\x22rfs\x22:[],\x22sbpl\x22:24,\x22sbpr\x22:24,\x22scd\x22:10,\x22sce\x22:5,\x22stok\x22:\x22FiKzKG5_wsVoNbvLTAAUkskuDv0\x22,\x22uhde\x22:false}}';google.pmc=JSON.parse(pmc);})();</script>        </body></html>

# %%
import urllib.request
import urllib.parse 

API = "https://search.naver.com/search.naver"
values={
    "sm":"top_hty",
    "fbm":"1",
    "ie":"utf8",
    "query":"초콜릿"
}
params = urllib.parse.urlencode(values) 
#한글이 있는 경우 인코딩을 해줘야 한다.

url= API +"?"+ params
print("url = ",url)
# Out:
# url =  https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%B4%88%EC%BD%9C%EB%A6%BF

# %%
import urllib.request
import urllib.parse 

API = "https://search.naver.com/search.naver"
values={
    "sm":"top_hty",
    "fbm":"1",
    "ie":"utf8",
    "query":"초콜릿"
}
params = urllib.parse.urlencode(values) 
#한글이 있는 경우 인코딩을 해줘야 한다.

url= API +"?"+ params
print("url = ",url)

data = urllib.request.urlopen(url).read()
text= data.decode("utf-8")
print(text)
# Out:
# url =  https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%B4%88%EC%BD%9C%EB%A6%BF
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="초콜릿 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'초콜릿'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'초콜릿'의 네이버 통합검색 결과입니다."> <title>초콜릿 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190221.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_190221.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_181122.css"><script type="text/javascript"> naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } function urlencode (q) { return escape(q).replace(/\+/g, "%2B") ; } function urlexpand (url) { var href = document.location.href ; if (url == "") return href ; if (url.match(/^[-.A-Za-z]+:/)) return url ; if (url.charAt(0) == '#') return href.split("#")[0] + url ; if (url.charAt(0) == '?') return href.split("?")[0] + url ; if (url.charAt(0) == '/') return href.replace(/([^:\/])\/.*$/, "$1") + url ; return href.substring(0, href.lastIndexOf("/")+1) + url ; } naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\s*;\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].append ...
#
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#         NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#         NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#         var parentElement = $Element(element).parent();
#         var timerAttribute = parentElement.attr("data-timer");
#         if (timerAttribute) {
#             clearTimeout(timerAttribute);
#             parentElement.attr("data-timer", "");
#         }
#         var tooltipElement = $Element(parentElement.query("._tooltip"));
#         tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#         var parentElement = $Element(element).parent();
#         if (!parentElement.attr("data-timer")) {
#             var timer = setTimeout(function () {
#                 var tooltipElement = $Element(parentElement.query("._tooltip"));
#                 tooltipElement.css("display", "none");
#             }, 100);
#             parentElement.attr("data-timer", timer);
#         }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#         if (_elAdIndLayerPl) {
#             adInfoHidePl();
#             return false;
#         } else {
#             if (!_elDscNcautionPl) {
#                 _elDscNcautionPl = $Element(el).parent();
#             }
#             _elDscNcautionPl._element.style.zIndex = 121;
#             _elAdIndLayerPl = $Element(el).next();
#             _elAdIndLayerPl.show();
#             _elAdIndLayerTimePl = (new Date()).getTime();
#             return true;
#         }
#     }
#
#     function adInfoHidePl() {
#         if (_elAdIndLayerPl) {
#             if (_elDscNcautionPl) {
#                 _elDscNcautionPl._element.style.zIndex = 0;
#             }
#             _elAdIndLayerPl.hide();
#             _elAdIndLayerPl = null;
#         }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#         if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
# </script>
# <link href="https://ssl.pstatic.net/sstatic/search/sa/180906/css/sa.css" rel="stylesheet" type="text/css" />
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css" />
# <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head"><h2>파워링크</h2>
#
#         <div class="dsc_ncaution">
#           <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">초콜릿</strong><em class="dsc_ncaution_quotation">&rsquo;</em></span>
#           <span class="dsc_ncaution_text">관련 광고입니다.</span>
#           <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#           <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none"><span class="ico_arr">&nbsp;</span>
#
#               <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#               <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#           </div>
#         </div>
#         <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=..._...">
#         <ul class="lst_type">
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="0" class="lst lst1">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=k5b0PEaFWRDP1awIDDI3MP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000057620322&amp;d=&#39; + urlencode(&#39;http://www.coupang.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">초콜릿 쿠팡</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=k5b0PEaFWRDP1awIDDI3MP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000057620322&amp;d=&#39;+urlencode(&#39;http://www.coupang.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.coupang.com</a>
#
#                     <p class="ad_dsc">
#                       <strong class='hl'>초콜릿</strong> 특가! 스낵, 간식, 시리얼, 금액제한없는 무료배송 로켓와우!
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="1" class="lst lst2">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=J+n8vhQZUuDcTDXCy2CFVv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000013415474&amp;d=&#39; + urlencode(&#39;http://www.chocolat.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">수제초콜릿 쇼콜라 미뇽</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=J+n8vhQZUuDcTDXCy2CFVv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000013415474&amp;d=&#39;+urlencode(&#39;http://www.chocolat.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.chocolat.co.kr</a>
#
#                     <p class="ad_dsc">
#                       프랑스식 수제 <strong class='hl'>초콜릿</strong>, 특별한 기념일을 위한 선물용 <strong class='hl'>초콜릿</strong> 세트 판매.
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="2" class="lst lst3">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=A010Rcl3bZ2ujRzjuHcRRP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000025502561&amp;d=&#39; + urlencode(&#39;http://www.da-heim.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">초콜릿, 다하임!</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=A010Rcl3bZ2ujRzjuHcRRP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000025502561&amp;d=&#39;+urlencode(&#39;http://www.da-heim.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.da-heim.com</a>
#           <span class="ico_area">
#             <span class="ico">
#               <span alt="네이버페이" class="sp_ad ico_npay" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
#               <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=3&amp;i=nad-a001-01-000000025502561&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디 하나로 간편구매</p>
#                   <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#
#
#           </span>
#                     <p class="ad_dsc">
#                       <strong class='hl'>초콜릿</strong>, 더 달콤하게, 나만의 특별한 선물, 재료부터 포장까지 한 번에!
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="3" class="lst lst4">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=m376uMPsUX5R3IPic0usLP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000055479002&amp;d=&#39; + urlencode(&#39;http://zimflower.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">찜꽃배달</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=m376uMPsUX5R3IPic0usLP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000055479002&amp;d=&#39;+urlencode(&#39;http://zimflower.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">zimflower.kr</a>
#           <span class="ico_area">
#             <span class="ico">
#               <span alt="네이버페이" class="sp_ad ico_npay" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
#               <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=4&amp;i=nad-a001-01-000000055479002&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디 하나로 간편구매</p>
#                   <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#             <span class="ico">
#               <span class="sp_ad ico_talktalk" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 톡톡</span>
#               <a class="ly_ad _tooltip" href="//talk.naver.com/intro" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.talktalk&amp;r=4&amp;i=nad-a001-01-000000055479002&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버톡톡으로 상담이 가능한 사이트입니다.</p>
#                   <p class="ly_ad_go"><strong>톡톡</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#           </span>
#                     <p class="ad_dsc">
#                       <strong class='hl'>초콜릿</strong>, 여자친구 감동시키는 화이트데이 <strong class='hl'>초콜릿</strong> 사탕 꽃바구니 꽃다발
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="4" class="lst lst5">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=QSsMHzrOc8ysmkCWKuLHw////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000039332022&amp;d=&#39; + urlencode(&#39;http://www.gsfresh.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">GS fresh 초콜릿</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=QSsMHzrOc8ysmkCWKuLHw////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000039332022&amp;d=&#39;+urlencode(&#39;http://www.gsfresh.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.gsfresh.com</a>
#           <span class="ico_area">
#
#             <span class="ico">
#               <span class="sp_ad ico_nlogin" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
#               <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=5&amp;i=nad-a001-01-000000039332022&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디로 로그인이 가능합니다.</p>
#                   <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#
#           </span>
#                     <p class="ad_dsc">
#                       <strong class='hl'>초콜릿</strong>, 출출할때 바로주문! 집에서도 먹고싶은 아이템, 간편한 건강 간식레시피
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="5" class="lst lst6">
#                 <div class="line"></div>
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=gVx9kPVUq9cVVP0U/pPTsP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000001640037&amp;d=&#39; + urlencode(&#39;http://www.hautechoco.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">해외 유명초콜릿 오뜨초코</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=gVx9kPVUq9cVVP0U/pPTsP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000001640037&amp;d=&#39;+urlencode(&#39;http://www.hautechoco.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.hautechoco.com</a>
#
#                     <p class="ad_dsc">
#                       해외브랜드 <strong class='hl'>초콜릿</strong>. 카페따스, 하세스, 니더레거, 타임세일 1+1 이벤트
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="6" class="lst lst7">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=C8/bEHeVFKI9ExhiQQ050////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000055195666&amp;d=&#39; + urlencode(&#39;https://www.lohbs.co.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">롭스 초콜릿</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=C8/bEHeVFKI9ExhiQQ050////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000055195666&amp;d=&#39;+urlencode(&#39;https://www.lohbs.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.lohbs.co.kr/</a>
#           <span class="ico_area">
#
#             <span class="ico">
#               <span class="sp_ad ico_nlogin" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
#               <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=7&amp;i=nad-a001-01-000000055195666&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디로 로그인이 가능합니다.</p>
#                   <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#
#           </span>
#                     <p class="ad_dsc">
#                       <strong class='hl'>초콜릿</strong> 신상템, 인기템부터 엘포인트 적립까지! 롭스에서 쇼핑하며 놀아볼까요?
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="7" class="lst lst8">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=5HJrXPES+ANVLry3vs/1Y////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000052957596&amp;d=&#39; + urlencode(&#39;http://www.gmarket.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">G마켓 초콜릿</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=5HJrXPES+ANVLry3vs/1Y////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000052957596&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.gmarket.co.kr</a>
#
#                     <p class="ad_dsc">
#                       쇼핑을 바꾸는 쇼핑! 현명한 쇼핑 습관, 1년 내내 12% 할인, <strong class='hl'>초콜릿</strong>
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="8" class="lst lst9">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=yOQ/jjkQ5vOubdVIFs6jxP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000026162418&amp;d=&#39; + urlencode(&#39;http://www.theobromachoco.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">테오브로마 쇼콜라티에</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=yOQ/jjkQ5vOubdVIFs6jxP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000026162418&amp;d=&#39;+urlencode(&#39;http://www.theobromachoco.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.theobromachoco.co.kr</a>
#           <span class="ico_area">
#             <span class="ico">
#               <span alt="네이버페이" class="sp_ad ico_npay" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
#               <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=9&amp;i=nad-a001-01-000000026162418&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디 하나로 간편구매</p>
#                   <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#
#
#           </span>
#                     <p class="ad_dsc">
#                       프랑스식 프리미엄 수제<strong class='hl'>초콜릿</strong> 전문점, 생<strong class='hl'>초콜릿</strong>, 가나슈<strong class='hl'>초콜릿</strong>, 강남 논현역 위치
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="9" class="lst lst10">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=R4UlBloWVLQmwA83INhEF////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000047958102&amp;d=&#39; + urlencode(&#39;http://www.11st.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">11번가 초콜릿</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=R4UlBloWVLQmwA83INhEF////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000047958102&amp;d=&#39;+urlencode(&#39;http://www.11st.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.11st.co.kr</a>
#
#                     <p class="ad_dsc">
#                       매일할인특가, T멤버십할인, 최대 22개월 무이자할부, OK캐쉬백 적립! <strong class='hl'>초콜릿</strong>
#
#                     </p>
#
#                 </div>
#             </li>
#         </ul>
#     </div>
#
#     <div class="ad_banner">
#         <span class="sp_ad ico_npay">네이버페이</span>마크는 네이버ID로 편리하고 안전하게 구매할 수 있는 네이버페이 사용처에 표시됩니다.<br />
#         네이버페이 사용처에서 구매하시면 네이버페이 포인트를 적립해드립니다.
#         <a class="more_mileage" href="//event2.pay.naver.com/event/benefit/list?frm=sa" onclick="return goOtherCR(this, 'a=mib_pwl.banner&r=0&i=mib_pwlbanner&u='+urlencode(this.href));" target="_blank">혜택 자세히 보기</a>
#     </div>
#     <div class="section_more">
#         <a class="go_site" target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%B4%88%EC%BD%9C%EB%A6%BF&amp;referenceId=U67zzlpVuF4ssbMePVRssssssps-098129" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#     </div>
# </div><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_shop_default_190327.css"> <script type="text/javascript">function shp_no_image(o, c) { o.onerror = null; o.src = 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif'; o.className = c; o.alt = '이미지 준비중';} </script> <div class="sp_shop_default section" id='_shopping_guide_view'> <div class="section_head"> <h2>네이버쇼핑</h2> <div class="dsc_ncaution2 _shopping_info_area"> <a href="#" onclick="return tCR('a=shp_gui.imark&r=&i=&u=javascript');" class="ico_ad_dsc _open_btn" title="이 정보가 표시된 이유">이 정보가 표시된 이유</a> <div class="ly_ad_dsc _layer" style="display:none;"> <span class="ico_arr">&nbsp;</span> <p>네이버가 운영하는 쇼핑 서비스입니다.</p> <button type="button" class="bt_ad_clse _close_btn" title="안내 레이어 닫기" onclick="return tCR('a=shp_gui.guideclose&r=&i=&u=javascript');">안내 레이어 닫기</button> </div> </div> <div class="dsc_ninfo">다른 사이트를 보시려면 <a href="?where=webkr&opt_src=site&sm=tab_shp&query=%EA%B0%80%EA%B2%A9%EB%B9%84%EA%B5%90%EC%82%AC%EC%9D%B4%ED%8A%B8+-%EB%84%A4%EC%9D%B4%EB%B2%84" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.pricesite');">여기</a>를 누르세요.</div> </div> <p class="title_desc title_desc_v2">'<em>초콜릿</em>' 상품 <a href="https://search.shopping.naver.com/search/all.nhn?query=%EC%B4%88%EC%BD%9C%EB%A6%BF&frm=NVSCPRO" onclick="return goOtherCR(this,'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.resultcount');" target="_blank">2,125,750</a>건</p> <div class="group_item"> <div class="tab_item"> <ul class="lst_tab _main_tab"> <li class="first tab _tab selected"> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*a.tab');"> <span class="sbar"><span></span></span> <span class="name" title="전체상품">전체상품</span> </a> </li> <li class="tab _tab"> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*h.tab');"> <span class="sbar"><span></span></span> <span class="name" title="핫딜">핫딜</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*9.tab');"> <span class="sbar"><span></span></span> <span class="name" title="키워드추천">키워드추천</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*6.tab');"> <span class="sbar"><span></span></span> <span class="name" title="중량">중량</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*7.tab');"> <span class="sbar"><span></span></span> <span class="name" title="식품품질인증">식품품질인증</span> </a> </li> </ul> <div class="tab_sub"> <div class="dsc_info _sub_tab_area" style="display:block;"><span class="spshop ico_info"></span>네이버는 상품판매의 당사자가 아니며, 구매 전 상품정보를 반드시 확인하시기 바랍니다. <a href="https://shopping.naver.com/user/legalbasis.nhn" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.law');">법적고지 및 안내</a><span class="spshop ico_arr"></span></div> <div class="dsc_info _sub_tab_area" style="display:none;"><span class="spshop ico_info"></span>네이버는 상품판매의 당사자가 아니며, 구매 전 상품정보를 반드시 확인하시기 바랍니다. <a href="https://shopping.naver.com/user/legalbasis.nhn" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.law');">법적고지 및 안내</a><span class="spshop ico_arr"></span></div> <ul class="lst_sub_tab _sub_tab_area" style="display:none;"> <li class='tab _tab first selected'> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*9.tab&g=etc_다크초콜릿');"> <span class="dot"></span> <span class="name" title="다크초콜릿">다크초콜릿</span> <span class="spshop ico_arr">선택됨</span> </a> </li> <li class='tab _tab '> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*9.tab&g=etc_대용량초콜릿');"> <span class="dot"></span> <span class="name" title="대용량초콜릿">대용량초콜릿</span> <span class="spshop ico_arr">선택됨</span> </a> </li> <li class='tab _tab '> <a href="#" class="stab _a" onclick="return tCR('u=javas ...
#         var _elAdIndLayerBz = null;
#         var _elAdIndLayerTimeBz;
#         var _elDscNcautionBz = null;
#
#         function adInfoShowBz(el) {
#             if (_elAdIndLayerBz) {
#                 adInfoHideBz();
#                 return false;
#             } else {
#                 if (!_elDscNcautionBz) {
#                     _elDscNcautionBz = $Element(el).parent();
#                 }
#                 _elDscNcautionBz._element.style.zIndex = 121;
#                 _elAdIndLayerBz = $Element(el).next();
#                 _elAdIndLayerBz.show();
#                 _elAdIndLayerTimeBz = (new Date()).getTime();
#                 return true;
#             }
#         }
#
#         function adInfoHideBz() {
#             if (_elAdIndLayerBz) {
#                 if (_elDscNcautionBz) {
#                     _elDscNcautionBz._element.style.zIndex = 0;
#                 }
#                 _elAdIndLayerBz.hide();
#                 _elAdIndLayerBz = null;
#             }
#         }
#
#         function adInfoHideClickEventHandlerBz(e) {
#             if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#         }
#
#         document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#     </script>
#     <div class="ad_section section _bz_section bg_type_v2">
#         <div class="section_head"><h2>비즈사이트</h2>
#             <div class="dsc_ncaution">
#               <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">초콜릿</strong><em class="dsc_ncaution_quotation">&rsquo;</em></span>
#               <span class="dsc_ncaution_text">관련 광고입니다.</span>
#                 <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowBz(this)) goOtherCR(this, &#39;a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#                 <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none"><span class="ico_arr">&nbsp;</span>
#                     <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#                     <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#                 </div>
#             </div>
#             <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a></div>
#         <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=..._...">
#             <ul class="lst_type ">
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="0" class="lst lst1">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=jhIGZTrhA1a54qF0q+42Xf///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000057613746&amp;d=&#39; + urlencode(&#39;http://www.hellonature.net&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">신선함이 문앞까지 헬로네이처</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=jhIGZTrhA1a54qF0q+42Xf///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000057613746&amp;d=&#39;+urlencode(&#39;http://www.hellonature.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.hellonature.net</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=jhIGZTrhA1a54qF0q+42Xf///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=1&amp;i=nad-a001-01-000000057613746&amp;d=&#39;+urlencode(&#39;http://www.hellonature.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 백가지 다양한 맛의 백미당. 유기농 재료를 활용한 남다른 품격의 디저트, <strong class='hl'>초콜릿</strong>
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="1" class="lst lst2">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=vEwrNMJs9hA/cjO+2TaYeP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=2&amp;i=nad-m001-01-000002043644954&amp;d=&#39; + urlencode(&#39;http://www.kimsbaking.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">추천학원 김상엽제과제빵학원</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=vEwrNMJs9hA/cjO+2TaYeP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=2&amp;i=nad-m001-01-000002043644954&amp;d=&#39;+urlencode(&#39;http://www.kimsbaking.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.kimsbaking.co.kr</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=vEwrNMJs9hA/cjO+2TaYeP///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=2&amp;i=nad-m001-01-000002043644954&amp;d=&#39;+urlencode(&#39;http://www.kimsbaking.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 <strong class='hl'>초콜릿</strong>, <strong class='hl'>초콜릿</strong>공예, <strong class='hl'>초코렛</strong>, 설탕공예,  기능장 직강, 제과제빵 전문학원.
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="2" class="lst lst3">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=s7nprNOC0CaF8/vnwQjZg////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000047294361&amp;d=&#39; + urlencode(&#39;http://www.dongsuhshop.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">동서직영쇼핑몰 동서Shop</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=s7nprNOC0CaF8/vnwQjZg////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000047294361&amp;d=&#39;+urlencode(&#39;http://www.dongsuhshop.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.dongsuhshop.com</a>
#             <span class="ico_area">
#
#               <span class="ico">
#                 <span class="sp_ad ico_nlogin" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
#                 <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" onclick="return goOtherCR(this, &#39;a=biz_nop.naverlogin&amp;r=3&amp;i=nad-a001-01-000000047294361&amp;u=&#39;+urlencode(this.href));">
#                   <span class="ly_box">
#                     <p>네이버 아이디로 로그인이 가능합니다.</p>
#                     <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                   </span>
#                     <span class="sp_ad ly_tail"></span>
#                 </a>
#               </span>
#
#
#             </span>
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=s7nprNOC0CaF8/vnwQjZg////w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=3&amp;i=nad-a001-01-000000047294361&amp;d=&#39;+urlencode(&#39;http://www.dongsuhshop.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 식자재류전문몰, 음료수, 커피, 치즈, 과일, 유지류등 판매, 각국의 식료품 판매
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="3" class="lst lst4">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=pPeViGn30HZesFx+I2nbmv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000046786537&amp;d=&#39; + urlencode(&#39;http://www.wemakeprice.com/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">위메프 초콜릿</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=pPeViGn30HZesFx+I2nbmv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000046786537&amp;d=&#39;+urlencode(&#39;http://www.wemakeprice.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.wemakeprice.com/</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=pPeViGn30HZesFx+I2nbmv///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=4&amp;i=nad-a001-01-000000046786537&amp;d=&#39;+urlencode(&#39;http://www.wemakeprice.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 최대 90% 역대급할인! 위메프 특가, 하나만 사도 무료배송, <strong class='hl'>초콜릿</strong>
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="4" class="lst lst5">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=hdQgpStH6N43RpGz9zi1Bf///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000049859883&amp;d=&#39; + urlencode(&#39;http://www.lottesuper.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">롯데슈퍼의 새이름 롯데프레시</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=hdQgpStH6N43RpGz9zi1Bf///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000049859883&amp;d=&#39;+urlencode(&#39;http://www.lottesuper.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.lottesuper.co.kr</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=hdQgpStH6N43RpGz9zi1Bf///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=5&amp;i=nad-a001-01-000000049859883&amp;d=&#39;+urlencode(&#39;http://www.lottesuper.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 <strong class='hl'>초콜릿</strong>, 첫구매고객은 신라면 100원! 간편하고 빠르게 3시간내 슈퍼배송!
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#             </ul>
#         </div>
#
#
#         <div class="section_more">
#             <a class="go_site" target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%B4%88%EC%BD%9C%EB%A6%BF&amp;referenceId=U67zzlpVuF4ssbMePVRssssssps-098129" onclick="return goOtherCR(this, &#39;a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#         </div>
#     </div><div class='result_more section' id='nx_result_more'> <div class='section_head'> <h2>검색결과 더보기</h2> </div> <div class='rsltmr_area'> <ul> <li><a target=_blank onclick="return goOtherCR(this, 'a=pst_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='http://m.post.naver.com/search/post.nhn?keyword=%EC%B4%88%EC%BD%9C%EB%A6%BF'><strong>포스트</strong><span class='site_more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=blg_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?query=%EC%B4%88%EC%BD%9C%EB%A6%BF&where=post&sm=tab_mre&nso='><strong>블로그</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=vdo_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=video&ie=utf8&nso=&sm=tab_mre&query=%EC%B4%88%EC%BD%9C%EB%A6%BF'><strong>동영상</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=kin_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='https://search.naver.com/search.naver?where=kin&query=%EC%B4%88%EC%BD%9C%EB%A6%BF&nso=so:r,a:all,p:all&sm=tab_mre'><strong>지식iN</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=img_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=image&query=%EC%B4%88%EC%BD%9C%EB%A6%BF&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&sm=tab_mre'><strong>이미지</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=caf_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=article&query=%EC%B4%88%EC%BD%9C%EB%A6%BF&ie=utf8&sm=tab_mre'><strong>카페</strong><span class='more'></span></a></li><li><a target=_blank onclick="return goOtherCR(this, 'a=app_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='https://s.search.naver.com/p/mobileapp/search.naver?where=svc&query=%EC%B4%88%EC%BD%9C%EB%A6%BF'><strong>앱정보</strong><span class='site_more'></span></a></li><li><a target=_blank onclick="return goOtherCR(this, 'a=loc_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='https://map.naver.com/?query=%EC%B4%88%EC%BD%9C%EB%A6%BF&type=SITE_1&queryRank=0'><strong>지도</strong><span class='site_more'></span></a></li> <li><div><span></span></div></li> <li><div><span></span></div></li> <li><div><span></span></div></li> <li><div><span></span></div></li> </ul> </div> </div> <script> nhn = window.nhn || {}; nhn.search = nhn.search || {}; nhn.search.ResultTabToggler = jindo.$Class({ _welWrapper: null, _welUl: null, _nLength: 0, _nWidth: 0, _nItemHeight: 0, _htConfig: {}, $init: function(b) { this._htConfig = this._validate(b); if (!$(this._htConfig.sId)) { return false; } this._welWrapper = jindo.$Element(this._htConfig.sId); this._welUl = jindo.$Element($$.getSingle("ul", this._welWrapper._element)); var a = $$("a", this._welWrapper._element); this._nLength = a.length; this._nItemHeight = jindo.$Element(a[0]).parent().height(); this._switchClass(); this._attachEvent(); }, _validate: function(b) { var c = { nMaxWidth: 795 }; for (var a in b) { if (b[a]) { c[a] = b[a]; } } return c; }, _attachEvent: function() { jindo.$Fn(this._switchClass, this).attach(window, "resize"); }, _getRow: function(c, a) { var b = 1; if (c % a > 0) { b = Math.ceil(c / a); } else { b = c / a; } return b; }, _switchClass: function() { var b = 4, c = 0, a = this._welWrapper.width(); if (a >= this._htConfig.nMaxWidth) { b = 5; this._welWrapper.addClass("result_more2"); } else { this._welWrapper.removeClass("result_more2"); } c = this._getRow(this._nLength, b); this._welUl.css("height", c * this._nItemHeight + "px"); } }); </script> <script type="text/javascript"> (function() { new nhn.search.ResultTabToggler({ sId : 'nx_result_more' }); }()); </script><script>g_crt+="";</script>
# <div class="collection"></div> </div><div id="sub_pack" class="sub_pack"><a href="https://alpha.naver.com/experiment/newnaverapp/beta?id=srh" target="_blank" onclick="return goOtherCR(this, 'a=bnr.link&r=&i=&u='+urlencode(this.href));" class="api_banner" style="background-color:#fff;"><img src="https://ssl.pstatic.net/sstatic/search/pc/tmp/ban_app_v3.png" width="400" height="60" class="img" alt="이제 iOS에서도 ‘새로운 네이버’를 경험해 보세요 이용방법 보기"></a><div class="z_aside section rktshp"> <div class="section_head"> <ul class="tab_kwd" role="tablist"><li data-index="0"><a href="#" role="tab">국내드라마 일간검색어</a></li><li class="selected" data-index="1"><a href="#" role="tab">과자/음료 쇼핑검색어</a></li></ul> </div> <div class="realtime_srch"> <h6 class="blind _blind">과자/음료 쇼핑검색어</h6> <ol class="lst_realtime_srch" style="display:none"> <li> <a href="?query=%EA%B5%AD%EB%AF%BC+%EC%97%AC%EB%9F%AC%EB%B6%84&ie=utf8&sm=tab_fid&rm=rkt_dra%2Cnexearch%2Csearch_extra%2C0" class="bx bx_item" title="국민 여러분" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=rkt_dra.list&amp;i=&amp;r=1')"> <span class="keyword"> <em class="num">1</em> <span class="tit">국민 여러분</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">33</span></em> </a> </li> <li> <a href="?query=%EC%97%B4%ED%98%88%EC%82%AC%EC%A0%9C&ie=utf8&sm=tab_fid&rm=rkt_dra%2Cnexearch%2Csearch_extra%2C0" class="bx bx_item" title="열혈사제" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=rkt_dra.list&amp;i=&amp;r=2')"> <span class="keyword"> <em class="num">2</em> <span class="tit">열혈사제</span> </span> <em class="rank down"><span class="spim">하락</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=%EC%9E%90%EB%B0%B1&ie=utf8&sm=tab_fid&rm=rkt_dra%2Cnexearch%2Csearch_extra%2C0" class="bx bx_item" title="자백" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=rkt_dra.list&amp;i=&amp;r=3')"> <span class="keyword"> <em class="num">3</em> <span class="tit">자백</span> </span> <em class="rank equal"><span class="spim">동일</span><span class="count">0</span></em> </a> </li> <li> <a href="?query=%ED%95%B4%EC%B9%98&ie=utf8&sm=tab_fid&rm=rkt_dra%2Cnexearch%2Csearch_extra%2C0" class="bx bx_item" title="해치" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=rkt_dra.list&amp;i=&amp;r=4')"> <span class="keyword"> <em class="num">4</em> <span class="tit">해치</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">18</span></em> </a> </li> <li> <a href="?query=%EC%9C%BC%EB%9D%BC%EC%B0%A8%EC%B0%A8+%EC%99%80%EC%9D%B4%ED%82%A4%ED%82%A4+2&ie=utf8&sm=tab_fid&rm=rkt_dra%2Cnexearch%2Csearch_extra%2C0" class="bx bx_item" title="으라차차 와이키키 2" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=rkt_dra.list&amp;i=&amp;r=5')"> <span class="keyword"> <em class="num">5</em> <span class="tit">으라차차 와이키키 2</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">7</span></em> </a> </li> <li> <a href="?query=%EC%84%B8%EC%83%81%EC%97%90%EC%84%9C+%EC%A0%9C%EC%9D%BC+%EC%98%88%EC%81%9C+%EB%82%B4+%EB%94%B8&ie=utf8&sm=tab_fid&rm=rkt_dra%2Cnexearch%2Csearch_extra%2C0" class="bx bx_item" title="세상에서 제일 예쁜 내 딸" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=rkt_dra.list&amp;i=&amp;r=6')"> <span class="keyword"> <em class="num">6</em> <span class="tit">세상에서 제일 예쁜 내 딸</span> </span> <em class="rank down"><span class="spim">하락</span><span class="count">4</span></em> </a> </li> <li> <a href="?query=%EB%8B%A5%ED%84%B0+%ED%94%84%EB%A6%AC%EC%A6%88%EB%84%88&ie=utf8&sm=tab_fid&rm=rkt_dra%2Cnexearch%2Csearch_extra%2C0" class="bx bx_item" title="닥터 프리즈너" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=rkt_dra.list&amp;i=&amp;r=7')"> <span class="keyword"> <em class="num">7</em> <span class="tit">닥터 프리즈너</span> </span> <em class="rank down"><span class="spim">하락</span><span class="count">2</span></em> ...

# %%
from bs4 import BeautifulSoup
import urllib.request as req

url = "http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp"

res= req.urlopen(url)
soup = BeautifulSoup(res,"html.parser")
title= soup.find("title").string
wf=soup.find("wf").string

print(title)
print(wf)
# Out:
# 기상청 육상 중기예보
# 7일은 기압골의 영향으로 중부지방과 전북에 비가 오겠고, 그 밖의 날은 고기압의 가장자리에 들어 가끔 구름많겠습니다.<br />기온은 평년(최저기온: 0~9℃, 최고기온: 14~20℃)과 비슷하겠습니다.<br />강수량은 평년(1~8mm)보다 적겠으나, 중부지방과 전북은 비슷하겠습니다.<br /><br />* 5일은 동해안과 강원산지에 바람이 매우 강하게 부는 곳이 있겠으니, 시설물 관리와 산불 등 화재예방에 유의하기 바랍니다.

# %%
class Service:
    secret = " 안녕"
    def sum(self,a,b):
        result=a+b
        print("%d + %d = %d이다"%(a,b,result))
pey= Service()
pey.sum(1,1)
# Out:
# 1 + 1 = 2이다
