# %%
import pandas as pd
import numpy as np

data  = pd.read_csv('./master.csv')

data.head()

data1=data[data['year']==2015]

data1
# Out:
#                    country  year     sex          age  suicides_no  \
# 576    Antigua and Barbuda  2015  female  55-74 years            1
# 577    Antigua and Barbuda  2015  female  15-24 years            0
# 578    Antigua and Barbuda  2015  female  25-34 years            0
# 579    Antigua and Barbuda  2015  female  35-54 years            0
# 580    Antigua and Barbuda  2015  female   5-14 years            0
# 581    Antigua and Barbuda  2015  female    75+ years            0
# 582    Antigua and Barbuda  2015    male  15-24 years            0
# 583    Antigua and Barbuda  2015    male  25-34 years            0
# 584    Antigua and Barbuda  2015    male  35-54 years            0
# 585    Antigua and Barbuda  2015    male   5-14 years            0
# 586    Antigua and Barbuda  2015    male  55-74 years            0
# 587    Antigua and Barbuda  2015    male    75+ years            0
# 948              Argentina  2015    male    75+ years          245
# ...

# %%
grouped= data1['suicides_no'].groupby(data1['country']).sum()
grouped
# Out:
# country
# Antigua and Barbuda                 1
# Argentina                        3073
# Armenia                            74
# Australia                        3027
# Austria                          1251
# Belgium                          1867
# Belize                             26
# Brazil                          11163
# Chile                            1838
# Colombia                         2332
# Croatia                           739
# Cuba                             1511
# Cyprus                             40
# Czech Republic                   1387
# Denmark                           564
# Ecuador                          1073
# Estonia                           195
# Finland                           731
# Georgia                           192
# Germany                         10088
# Greece                            529
# Grenada                             0
# Guatemala                         494
# Hungary                          1868
# ...
